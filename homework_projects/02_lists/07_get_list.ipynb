# %%
def main():
    lst = []
    val = input("Enter a value: ")
    while val:
        lst.append(val)
        val = input("Enter a value: ")
    print("Here's the list:", lst)

if __name__ == "__main__":
    main()
# Out:
# Enter a value: 1
# Enter a value: 2
# Enter a value:
# Here's the list: ['1', '2']
